# %% [markdown]
# # Dorathy

# %%
import twint
import nest_asyncio

# %%
nest_asyncio.apply()

c = twint.Config()

c.Search = 'dorathy'
c.Since = '2020-09-11'
c.Until = '2020-09-12'
c.Store_csv = True
c.Output = 'Scraped_tweets/dorathy.csv'

twint.run.Search(c)
# Out:
# 1304397297665662976 2020-09-11 13:32:04 GMT Summer Time <jimcust> How much do major oil discoveries change expectations about the future?   New World Bank research finds an 'expectations boom' with more babies and less emigration.  Link to paper:   http://documents1.worldbank.org/curated/en/796881598889032254/pdf/Natural-Resource-Discoveries-Citizen-Expectations-and-Household-Decisions.pdf …  Expectations boom leads to: Incr. fertility Decr. apps to US green card pic.twitter.com/ZrIIcvYR7O
# 1304397297665662976 2020-09-11 13:32:04 GMT Summer Time <jimcust> How much do major oil discoveries change expectations about the future?   New World Bank research finds an 'expectations boom' with more babies and less emigration.  Link to paper:   http://documents1.worldbank.org/curated/en/796881598889032254/pdf/Natural-Resource-Discoveries-Citizen-Expectations-and-Household-Decisions.pdf …  Expectations boom leads to: Incr. fertility Decr. apps to US green card pic.twitter.com/ZrIIcvYR7O
# ...
