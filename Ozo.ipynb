# %% [markdown]
# # OZO

# %%
import twint
import nest_asyncio

# %%
nest_asyncio.apply()

c = twint.Config()

c.Search = 'ozo'
c.Since = '2020-09-11'
c.Until = '2020-09-12'
c.Store_csv = True
c.Output = 'Scraped_tweets/ozo.csv'

twint.run.Search(c)
# Out:
# 1304397297665662976 2020-09-11 13:32:04 GMT Summer Time <jimcust> How much do major oil discoveries change expectations about the future?   New World Bank research finds an 'expectations boom' with more babies and less emigration.  Link to paper:   http://documents1.worldbank.org/curated/en/796881598889032254/pdf/Natural-Resource-Discoveries-Citizen-Expectations-and-Household-Decisions.pdf …  Expectations boom leads to: Incr. fertility Decr. apps to US green card pic.twitter.com/ZrIIcvYR7O
# 1304418093985394689 2020-09-11 14:54:43 GMT Summer Time <FriendsofEurope> How can Africa and the EU build a a strong partnership to roll-out cleaner, more sustainable and secure energy access, resilient infrastructure, and regional integration for energy security?   Watch the debate to find out! #DebatingAfricaEU
# ...
